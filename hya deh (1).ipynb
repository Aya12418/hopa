# %%
import time
import pandas as pd
import numpy as np

CITY_DATA = { 'chicago': 'chicago.csv',
              'new york city': 'new_york_city.csv',
              'washington': 'washington.csv' }

def get_filters():
    city = city_input()
    day = day_input()
    month = month_input()
     return city, month, day
    """
    Asks user to specify a city, month, and day to analyze.

    Returns:
        (str) city - name of the city to analyze
        (str) month - name of the month to filter by, or "all" to apply no month filter
        (str) day - name of the day of week to filter by, or "all" to apply no day filter
    """
    print('Hello! Let\'s explore some US bikeshare data!')
    # TO DO: get user input for city (chicago, new york city, washington). HINT: Use a while loop to handle invalid inputs
def city_input():
    city =input('kindly select the city you want to analysis (chicago, new york, washington :').lower()
    while city not in ['chicago','new york','washington']:
         city = input ("Your selection invalid please enter from this list ( chicago , new york , washington : )")
            
    print(city)
     return city, month, day


    # TO DO: get user input for month (all, january, february, ... , june)
def month_input():
    month =input('Which month you want to see  (All,January, February, March, April, May, June :').title()
    while month not in ['All','January', 'February', 'March', 'April', 'May', 'June']:
         month = input ("Your selection invalid please enter from this list ( All,January, February, March, April, May, June :)")
            
    print(month)
     return city, month, day


    # TO DO: get user input for day of week (all, monday, tuesday, ... sunday)
def day_input():
    day =input('Which day of week would like to analysis (All, Monday, Tuesday, Wednesday, Thursday, Friday, Saturday, Sunday :').title()
    while day not in ['All','Monday', 'Tuesday', 'Wednesday', 'Thursday','Friday', 'Saturday', 'Sunday']:
         day = input ("Your selection invalid please enter from this list (All, Monday, Tuesday, Wednesday, Thursday, Friday, Saturday, Sunday :)")
            
    print(day)
    return city, month, day


    print('-'*40)
     return city, month, day
# Out:
#   File "<ipython-input-1-34eec98cfca7>", line 13
#     return city, month, day
#     ^
# IndentationError: unexpected indent
